# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanika018/computer-vision/blob/master/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("dog.jpeg")
print(img)
# Out:
# [[[110 183 187]
#   [104 178 180]
#   [ 99 168 171]
#   ...
#   [ 35 122 118]
#   [ 28 112 108]
#   [ 17 101  97]]
#
#  [[111 179 184]
#   [106 175 178]
#   [100 167 168]
#   ...
#   [ 27 114 110]
#   [ 21 105 101]
#   [ 10  94  90]]
#
#  [[113 176 180]
#   [110 171 173]
#   [105 164 166]
#   ...
#   [ 16 103 100]
#   [ 10  94  92]
#   [  1  85  83]]
#
#  ...
#
#  [[ 81 141 111]
#   [ 34  96  66]
#   [  9  73  43]
#   ...
#   [ 73 119  96]
#   [ 74 115  94]
#   [ 69 110  89]]
#
#  [[ 46 102  73]
#   [ 43 101  72]
#   [ 49 111  81]
#   ...
#   [ 91 137 115]
#   [ 93 130 114]
#   [ 89 125 109]]
#
#  [[ 54 108  78]
#   [ 49 106  75]
#   [ 48 108  78]
#   ...
#   [ 98 140 122]
#   [103 137 126]
#   [106 138 127]]]

# %%
print(img.shape)
# Out:
# (183, 275, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[0:180,0:150])

# %%
plt.imshow(img[0:180,151:250])

# %%
 
img = cv2.imread('dog.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray)
plt.title('my picture')
plt.show()

# %%
from IPython.display import Image
from IPython.display import display
x = Image(filename='dog.jpeg') 
y = Image(filename='dog.jpeg') 
display(x, y)
